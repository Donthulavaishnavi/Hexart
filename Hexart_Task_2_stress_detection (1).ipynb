# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("/content/drive/MyDrive/Datasets /stress2")

# %%
data
# Out:
#          sr      rr       t      lm      bo     rem   sr.1     hr  sl
# 0    93.800  25.680  91.840  16.600  89.840   99.60  1.840  74.20   3
# 1    91.640  25.104  91.552  15.880  89.552   98.88  1.552  72.76   3
# 2    60.000  20.000  96.000  10.000  95.000   85.00  7.000  60.00   1
# 3    85.760  23.536  90.768  13.920  88.768   96.92  0.768  68.84   3
# 4    48.120  17.248  97.872   6.496  96.248   72.48  8.248  53.12   0
# ..      ...     ...     ...     ...     ...     ...    ...    ...  ..
# 625  69.600  20.960  92.960  10.960  90.960   89.80  3.440  62.40   2
# 626  48.440  17.376  98.064   6.752  96.376   73.76  8.376  53.44   0
# 627  97.504  27.504  86.880  17.752  84.256  101.88  0.000  78.76   4
# 628  58.640  19.728  95.728   9.728  94.592   84.32  6.728  59.32   1
# 629  73.920  21.392  93.392  11.392  91.392   91.96  4.088  63.48   2
#
# [630 rows x 9 columns]

# %%
data.shape
# Out:
# (630, 9)

# %%
data.head()
# Out:
#       sr      rr       t      lm      bo    rem   sr.1     hr  sl
# 0  93.80  25.680  91.840  16.600  89.840  99.60  1.840  74.20   3
# 1  91.64  25.104  91.552  15.880  89.552  98.88  1.552  72.76   3
# 2  60.00  20.000  96.000  10.000  95.000  85.00  7.000  60.00   1
# 3  85.76  23.536  90.768  13.920  88.768  96.92  0.768  68.84   3
# 4  48.12  17.248  97.872   6.496  96.248  72.48  8.248  53.12   0

# %%
data.tail()
# Out:
#          sr      rr       t      lm      bo     rem   sr.1     hr  sl
# 625  69.600  20.960  92.960  10.960  90.960   89.80  3.440  62.40   2
# 626  48.440  17.376  98.064   6.752  96.376   73.76  8.376  53.44   0
# 627  97.504  27.504  86.880  17.752  84.256  101.88  0.000  78.76   4
# 628  58.640  19.728  95.728   9.728  94.592   84.32  6.728  59.32   1
# 629  73.920  21.392  93.392  11.392  91.392   91.96  4.088  63.48   2

# %%
data.describe()
# Out:
#                sr          rr          t          lm          bo         rem  \
# count  630.000000  630.000000  630.00000  630.000000  630.000000  630.000000
# mean    71.600000   21.800000   92.80000   11.700000   90.900000   88.500000
# std     19.372833    3.966111    3.52969    4.299629    3.902483   11.893747
# min     45.000000   16.000000   85.00000    4.000000   82.000000   60.000000
# 25%     52.500000   18.500000   90.50000    8.500000   88.500000   81.250000
# 50%     70.000000   21.000000   93.00000   11.000000   91.000000   90.000000
# 75%     91.250000   25.000000   95.50000   15.750000   94.250000   98.750000
# max    100.000000   30.000000   99.00000   19.000000   97.000000  105.000000
#
#              sr.1          hr          sl
# count  630.000000  630.000000  630.000000
# mean     3.700000   64.500000    2.000000
# std      3.054572    9.915277    1.415337
# min      0.000000   50.000000    0.000000
# 25%      0.500000   56.250000    1.000000
# 50%      3.500000   62.500000    2.000000
# 75%      6.500000   72.500000    3.000000
# max      9.000000   85.000000    4.000000

# %%
data.isnull().sum()
# Out:
# sr      0
# rr      0
# t       0
# lm      0
# bo      0
# rem     0
# sr.1    0
# hr      0
# sl      0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630 entries, 0 to 629
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sr      630 non-null    float64
#  1   rr      630 non-null    float64
#  2   t       630 non-null    float64
#  3   lm      630 non-null    float64
#  4   bo      630 non-null    float64
#  5   rem     630 non-null    float64
#  6   sr.1    630 non-null    float64
#  7   hr      630 non-null    float64
#  8   sl      630 non-null    int64
# dtypes: float64(8), int64(1)
# memory usage: 44.4 KB

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data['sl'].value_counts()
# Out:
# 3    126
# 1    126
# 0    126
# 2    126
# 4    126
# Name: sl, dtype: int64

# %%
data.dtypes
# Out:
# sr      float64
# rr      float64
# t       float64
# lm      float64
# bo      float64
# rem     float64
# sr.1    float64
# hr      float64
# sl        int64
# dtype: object

# %%
x1=data['sr']
y1=data['sl']
plt.plot(x1,y1)

# %%
x2=data['rr']
y2=data['sl']
plt.plot(x2,y2)

# %%
x=data.iloc[:,0:8]

# %%
x
# Out:
#          sr      rr       t      lm      bo     rem   sr.1     hr
# 0    93.800  25.680  91.840  16.600  89.840   99.60  1.840  74.20
# 1    91.640  25.104  91.552  15.880  89.552   98.88  1.552  72.76
# 2    60.000  20.000  96.000  10.000  95.000   85.00  7.000  60.00
# 3    85.760  23.536  90.768  13.920  88.768   96.92  0.768  68.84
# 4    48.120  17.248  97.872   6.496  96.248   72.48  8.248  53.12
# ..      ...     ...     ...     ...     ...     ...    ...    ...
# 625  69.600  20.960  92.960  10.960  90.960   89.80  3.440  62.40
# 626  48.440  17.376  98.064   6.752  96.376   73.76  8.376  53.44
# 627  97.504  27.504  86.880  17.752  84.256  101.88  0.000  78.76
# 628  58.640  19.728  95.728   9.728  94.592   84.32  6.728  59.32
# 629  73.920  21.392  93.392  11.392  91.392   91.96  4.088  63.48
#
# [630 rows x 8 columns]

# %%
y=data.iloc[:,8:9]

# %%
y
# Out:
#      sl
# 0     3
# 1     3
# 2     1
# 3     3
# 4     0
# ..   ..
# 625   2
# 626   0
# 627   4
# 628   1
# 629   2
#
# [630 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y, test_size=0.2,random_state=10)

# %%
x_train
# Out:
#          sr      rr       t      lm      bo     rem   sr.1     hr
# 105  61.440  20.144  92.144  10.144  90.144   85.72  2.216  60.36
# 238  83.120  22.832  90.416  13.040  88.416   96.04  0.416  67.08
# 72   57.680  19.536  95.536   9.536  94.304   83.84  6.536  58.84
# 602  56.960  19.392  95.392   9.392  94.088   83.48  6.392  58.48
# 559  51.440  18.288  94.288   8.288  92.432   80.72  5.288  55.72
# ..      ...     ...     ...     ...     ...     ...    ...    ...
# 369  92.240  25.264  91.632  16.080  89.632   99.08  1.632  73.16
# 320  91.160  24.976  91.488  15.720  89.488   98.72  1.488  72.44
# 527  96.544  26.544  85.680  17.272  82.816  100.68  0.000  76.36
# 125  98.112  28.112  87.640  18.056  85.168  102.64  0.000  80.28
# 265  56.160  19.232  95.232   9.232  93.848   83.08  6.232  58.08
#
# [504 rows x 8 columns]

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
l=model.score(x_test,y_test)
print(l)
# Out:
# 1.0
